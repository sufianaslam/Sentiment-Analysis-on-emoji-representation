# %%
import numpy as np

# %%
i=0
j=0
t_list=[]
new = []
emoji_class=[]
with open('emoList.txt', encoding="utf8") as f:
    
    for line in f:
        clas_emoji=[]
        if(line.startswith('#')):
            clas_emoji = line.split(' ')
            print(clas_emoji[2],i)
            
            emoji_class.append(clas_emoji[2])
            if(i>=1):
                t_list.append(new)
                new=[]
            i+=1
            #Subclass functions below\
        elif(line!='\n'):
            
            word=line.split(' ')
            if(word[0]!='\n'):
                print(word[5])
                emoji=word[1].split(';')
                
            eword=line.split('#')
            emoji=eword[1].split(' ')
            print(emoji[1])
            new.append(emoji[1])
t_list.append(new)
# Out:
# face-smiling
#  0
#
# 😀
#
# 😃
#
# 😄
#
# 😁
#
# 😆
#
# 😅
#
# 🤣
#
# 😂
#
# 🙂
#
# 🙃
#
# 😉
#
# 😊
#
# 😇
# face-affection
#  1
#
# 🥰
#
# 😍
#
# 🤩
#
# 😘
#
# 😗
#
# ☺️
#
# ☺
#
# 😚
#
# 😙
# face-tongue
#  2
#
# 😋
#
# 😛
#
# 😜
#
# 🤪
#
# 😝
#
# 🤑
# face-hand
#  3
#
# 🤗
#
# 🤭
#
# 🤫
#
# 🤔
# face-neutral-skeptical
#  4
#
# 🤐
#
# 🤨
#
# 😐
#
# 😑
#
# 😶
#
# 😏
#
# 😒
#
# 🙄
#
# 😬
#
# 🤥
# face-sleepy
#  5
#
# 😌
#
# 😔
#
# 😪
#
# 🤤
#
# 😴
# face-unwell
#  6
#
# 😷
#
# 🤒
#
# 🤕
#
# 🤢
#
# 🤮
#
# 🤧
#
# 🥵
#
# 🥶
#
# 🥴
#
# 😵
#
# 🤯
# face-hat
#  7
#
# 🤠
#
# 🥳
# face-glasses
#  8
#
# 😎
#
# 🤓
#
# 🧐
# face-concerned
#  9
#
# 😕
#
# 😟
#
# 🙁
#
# ☹️
#
# ☹
#
# 😮
#
# 😯
#
# 😲
#
# 😳
#
# 🥺
#
# 😦
#
# 😧
#
# 😨
#
# 😰
#
# 😥
#
# 😢
#
# 😭
#
# 😱
#
# 😖
#
# 😣
#
# 😞
#
# 😓
#
# 😩
#
# 😫
#
# 🥱
# face-negative
#  10
#
# 😤
#
# 😡
#
# 😠
#
# 🤬
#
# 😈
#
# 👿
#
# 💀
#
# ☠️
#
# ☠
# face-costume
#  11
#
# 💩
#
# 🤡
#
# 👹
#
# 👺
#
# 👻
#
# 👽
#
# 👾
#
# 🤖
# cat-face
#  12
#
# 😺
#
# 😸
#
# 😹
#
# 😻
#
# 😼
#
# 😽
#
# 🙀
#
# 😿
#
# 😾
# monkey-face
#  13
#
# 🙈
#
# 🙉
#
# 🙊
# emotion
# ...

# %%
g=[]
for i in range(len(t_list)):
    g.append([emoji_class[i],t_list[i]])

# %%
len(t_list)
# Out:
# 15

# %%
emoji_class
# Out:
# ['face-smiling\n',
#  'face-affection\n',
#  'face-tongue\n',
#  'face-hand\n',
#  'face-neutral-skeptical\n',
#  'face-sleepy\n',
#  'face-unwell\n',
#  'face-hat\n',
#  'face-glasses\n',
#  'face-concerned\n',
#  'face-negative\n',
#  'face-costume\n',
#  'cat-face\n',
#  'monkey-face\n',
#  'emotion\n']

# %%
g[0][1]
# Out:
# ['😀', '😃', '😄', '😁', '😆', '😅', '🤣', '😂', '🙂', '🙃', '😉', '😊', '😇']
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\armug\Anaconda3_new\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\armug\Anaconda3_new\lib\asyncio\selector_events.py", line 125, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\armug\Anaconda3_new\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\armug\Anaconda3_new\lib\asyncio\selector_events.py", line 125, in _read_from_self
# ...
